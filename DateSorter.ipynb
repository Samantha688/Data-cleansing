# %%
import pandas as pd

doc = []
with open('dates.txt') as file:
    for line in file:
        doc.append(line)
df = pd.Series(doc)
df.head(10)

t = re.compile(r'(?:\d{1,2})[\s/-](?:\d{1,2}|)?(?:th|rd|st|nd)?(?:,)?[\s/-]\d{2,4}')
w = re.compile(r'(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec|January|February|March|April|May|June|July|August|September|October|November|December)(?:.)?[\s/-]\d{1,2}(?:th|rd|st|nd)?(?:,)?[\s/-]\d{2,4}')
q = re.compile(r'\d{1,2}[\s/-](?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec|January|February|March|April|May|June|July|August|September|October|November|December)[\s/-]\d{2,4}')
k = re.compile(r'(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec|January|February|March|April|May|June|July|August|September|October|November|December)(?:.)?[\s/-]\d{2,4}')
o = re.compile(r'\d{1,2}(?:th|rd|st|nd)?(?:,)?[\s/-]\d{2,4}')
p = re.compile(r'\d{4}')

datelist = {}
for i in range(0,len(df)):
    s = re.findall(t,df.iloc[i])
    datelist[df.iloc[i]] = s
    if s == []:
        s = re.findall(w,df.iloc[i])
        datelist[df.iloc[i]] = s
        if s == []:
            s = re.findall(q,df.iloc[i])
            datelist[df.iloc[i]] = s
            if s == []:
                s = re.findall(k ,df.iloc[i])
                datelist[df.iloc[i]] = s
                if s == []:
                    s = re.findall(o ,df.iloc[i])
                    datelist[df.iloc[i]] = s
                    if s == []:
                        s = re.findall(p ,df.iloc[i])
                        datelist[df.iloc[i]] = s
df[313] = df[313].replace("Decemeber", "December")
pd.set_option('display.max_rows', None)
e = pd.DataFrame(datelist.values())[0]
for i in range(0,500):
    if e[i][-3:][0] == '/' or e[i][-3:][0] == '-':
        o = e[i][:-2] + '19' + e[i][-2:]
        e[i] = o
for i in range(0,500):
    if len(e[i]) == 4:
        o = '01/01/' + e[i]
        e[i] = o
for i in range(0,500):
    if (len(e[i]) == 7 or len(e[i]) == 6)and e[i][-5:][0] == '/':
        o = e[i][:-4] + '01/' + e[i][-4:]
        e[i] = o
for i in range(0,500):
    s = e[i].replace(",", "")
    e[i] = s
for i in range(0,500):
    s = e[i].replace(".", "")
    e[i] = s
capmonthlist = {'January':'Jan', 'February':'Feb', 'March':'Mar','April':'Apr','June':'Jun','July':'Jul', 'August':'Aug', 'September':'Sep','October':'Oct','November':'Nov','December':'Dec'}
for i in range(0,500):
    for k,v in capmonthlist.items():
        if k in e[i]:
            s = e[i].replace(k,v)
            e[i] = s
monthlist = {'Jan':'01', 'Feb':'02', 'Mar': '03','Apr': '04','May':'05','Jun':'06','Jul':'07', 'Aug':'08', 'Sep':'09','Oct':'10','Nov':'11','Dec':'12'}
for i in range(0,500):
    for k,v in monthlist.items():
        if e[i][-8:-5] == k and len(e[i]) == 8:
            o =  v+'/'+ '01/'+e[i][-4:]
            e[i] = o
for i in range(0,500):
    for k,v in monthlist.items():
        if e[i][-8:-5] == k and len(e[i]) == 11:
            o =  v + '/'+ e[i][:2]+'/' +e[i][-4:]
            e[i] = o
for i in range(0,500):
    for k,v in monthlist.items():
        if e[i][:3] == k and len(e[i]) == 11:
            o =  v + '/'+ e[i][-7:-5]+'/' +e[i][-4:]
            e[i] = o

e[392] = '05/01/2000'
e[461] = '01/01/1991'
e[465] = '01/01/1976'
e[490] = '01/01/2007'

for i in range(0,500):
    e[i].replace('-','/')

new = pd.to_datetime(e)
#df_2 = pd.DataFrame(new)
#result = pd.Series(df_2.sort_values(by = [0], kind="stable").index)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 88
#      85 for i in range(0,500):
#      86     e[i].replace('-','/')
# ---> 88 new = pd.to_datetime(e)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1067, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1065         result = arg.map(cache_array)
#    1066     else:
# -> 1067         values = convert_listlike(arg._values, format)
#    1068         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1069 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:433, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
# ...
